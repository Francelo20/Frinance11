# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
##from jupyterthemes import jtplot

data = pd.read_json("final.json")
sns.set_theme() ##style="ticks"/dark, whitegrid..., palette="pastel"
sns.pairplot(data, x_vars=['percin', 'percat', 'difsupperc',
       'difresperc', 'acumperc', 'maxperc'], y_vars=["final"], height=3, palette="Set2", aspect=1, hue="qualymes");#, kind="reg"

# %%
'''
sum_x=data['acumperc'].sum()
'rmaxtu', 'maxperc', 'minperc'
sum_y=data['final'].sum()

mean_x=data['acumperc'].mean()

mean_y=data['final'].mean()

prod_x_y=(data['acumperc']*data['final']).sum()

x_squared=(data['acumperc']*data['acumperc']).sum()

sum_x_squared=sum_x**2

first_term=((prod_x_y-((sum_x*sum_y)/319))/(x_squared-(sum_x**2)/319))
second_term=mean_y -(first_term*mean_x)

plt.scatter(data['acumperc'], data['final'])

y2=[]
for i in range(-4,3):
    y2.append(first_term+second_term*i)

y2=pd.DataFrame(y2, index=range(-4,3))
y2.to_csv('Y2_test.csv')

plt.plot(y2['0'], 'r')
plt.show()
'''
##data = data.dropna()
##data.corr()
##jtplot.style()

##sns.pairplot(data)
##sns.lmplot(x="acumperc", y="final", data=data, markers="o", palette="Set3", hue="qualymes") ##, x_jitter=.05 ooou x_estimator=np.mean

##sns.lmplot(x="x", y="y", data=anscombe.query("data == 'II'"), ci=None, scatter_kws={"s": 80})

##relplot
##plt.xticks(fontsize=14)
##plt.yticks(fontsize=14)
##print(data)
##sns.jointplot(x="acumperc", y="final", data=data, kind="reg") ##kind="kde"
##sns.relplot(data=data, x="acumperc", y="final",hue="rmaxtu", col="qualymes")
##fig =sns.relplot(data=data, x="acumperc", y="final",hue="qualymes")
##fig=sns.lineplot(data=data, x="acumperc", y="final",hue="qualymes")
##fig=sns.displot(data=data, x="final", kind="kde") ##displot é sem y##
##sns.pairplot(data, y_vars=['final'], kind="reg",height=10, aspect=1,  corner=False)
##fig.set_titles("Francelo resp")
##sns.scatterplot(data=data, x="acumperc", y="final",hue="qualymes", palette=['red','dark'])
##plt.show(fig)

'''
x="acumperc", y="final", col="time",

volume"pouco volume sobe mais
"gelo"
"percgel"   2 mais alta subiram maiss discrepancia? sinal de que estava disparada?
"percin"    2 mais alta subiram maiss discrepancia? sinal de que estava disparada?
"percat"    2 mais alta subiram maiss discrepancia? sinal de que estava disparada?
"difpercatin" o proximos de zero subiram mais
"preop"     n
"prein"     n
"preat"     n
"presup"    nada
"difsupperc" nada
"preres"    nada
"difresperc" nada
"qualymes" **** 3, 6, 33, 66, subiram. 3333 6333 nao subiram
"rmaxtu" entre 0.2 e 0.5 sao as que mais subiram...e cairam
"acumperc"***** todas acum positivo terminaram acum positivo. e concentraram os maiores acums
maxperc"   maiores que 1.0 não negativaram
"minperc" minperc zero subiram mais
"aumeperc -0.5 concentram os mais altos. positivos nao subiram

import pandas as pd
import sklearn.model_selection as ms
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import numpy as np


######################################
# Importa o dataset
######################################


dataset = pd.read_csv("reg01.csv")
dataset = dataset.dropna()
X = dataset.iloc[:, :-2]
y = dataset.iloc[:, -1]

######################################
# Codificando variaveis Dummy
######################################
X_dummies = pd.get_dummies(X)

print(X_dummies)
'''
